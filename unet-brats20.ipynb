# %%
import os
import cv2
import glob
import PIL
import shutil
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from skimage import data
from skimage.util import montage 
import skimage.transform as skTrans
from skimage.transform import rotate
from skimage.transform import resize
from PIL import Image, ImageOps  


# neural imaging
import nilearn as nl
import nibabel as nib
import nilearn.plotting as nlplt



# ml libs
import keras
import keras.backend as K
from keras.callbacks import CSVLogger
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.layers.experimental import preprocessing


# Make numpy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# DEFINE seg-areas  
SEGMENT_CLASSES = {
    0 : 'NOT tumor',
    1 : 'NECROTIC/CORE', # or NON-ENHANCING tumor CORE
    2 : 'EDEMA',
    3 : 'ENHANCING' # original 4 -> converted into 3 later
}

# there are 155 slices per volume
# to start at 5 and use 145 slices means we will skip the first 5 and last 5 
VOLUME_SLICES = 100 
VOLUME_START_AT = 22 # first slice of volume that we will include

# %%
TRAIN_DATASET_PATH = '../input/brats20-dataset-training-validation/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/'
VALIDATION_DATASET_PATH = '../input/brats20-dataset-training-validation/BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData'

test_image_flair=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_flair.nii').get_fdata()
test_image_t1=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_t1.nii').get_fdata()
test_image_t1ce=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_t1ce.nii').get_fdata()
test_image_t2=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_t2.nii').get_fdata()
test_mask=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_seg.nii').get_fdata()


fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1,5, figsize = (20, 10))
slice_w = 25
ax1.imshow(test_image_flair[:,:,test_image_flair.shape[0]//2-slice_w], cmap = 'gray')
ax1.set_title('Image flair')
ax2.imshow(test_image_t1[:,:,test_image_t1.shape[0]//2-slice_w], cmap = 'gray')
ax2.set_title('Image t1')
ax3.imshow(test_image_t1ce[:,:,test_image_t1ce.shape[0]//2-slice_w], cmap = 'gray')
ax3.set_title('Image t1ce')
ax4.imshow(test_image_t2[:,:,test_image_t2.shape[0]//2-slice_w], cmap = 'gray')
ax4.set_title('Image t2')
ax5.imshow(test_mask[:,:,test_mask.shape[0]//2-slice_w])
ax5.set_title('Mask')
# Out:
# Text(0.5, 1.0, 'Mask')

# %%
# Skip 50:-50 slices since there is not much to see
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(test_image_t1[50:-50,:,:]), 90, resize=True), cmap ='gray')

# %%
# Skip 50:-50 slices since there is not much to see
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(test_mask[60:-60,:,:]), 90, resize=True), cmap ='gray')

# %%
niimg = nl.image.load_img(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_flair.nii')
nimask = nl.image.load_img(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_seg.nii')

fig, axes = plt.subplots(nrows=4, figsize=(30, 40))


nlplt.plot_anat(niimg,
                title='BraTS20_Training_001_flair.nii plot_anat',
                axes=axes[0])

nlplt.plot_epi(niimg,
               title='BraTS20_Training_001_flair.nii plot_epi',
               axes=axes[1])

nlplt.plot_img(niimg,
               title='BraTS20_Training_001_flair.nii plot_img',
               axes=axes[2])

nlplt.plot_roi(nimask, 
               title='BraTS20_Training_001_flair.nii with mask plot_roi',
               bg_img=niimg, 
               axes=axes[3], cmap='Paired')

plt.show()

# %%
# dice loss as defined above for 4 classes
def dice_coef(y_true, y_pred, smooth=1.0):
    class_num = 4
    for i in range(class_num):
        y_true_f = K.flatten(y_true[:,:,:,i])
        y_pred_f = K.flatten(y_pred[:,:,:,i])
        intersection = K.sum(y_true_f * y_pred_f)
        loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
   #     K.print_tensor(loss, message='loss value for class {} : '.format(SEGMENT_CLASSES[i]))
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
#    K.print_tensor(total_loss, message=' total dice coef: ')
    return total_loss


 
# define per class evaluation of dice coef
# inspired by https://github.com/keras-team/keras/issues/9395
def dice_coef_necrotic(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,1] * y_pred[:,:,:,1]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,1])) + K.sum(K.square(y_pred[:,:,:,1])) + epsilon)

def dice_coef_edema(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,2] * y_pred[:,:,:,2]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,2])) + K.sum(K.square(y_pred[:,:,:,2])) + epsilon)

def dice_coef_enhancing(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,3] * y_pred[:,:,:,3]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,3])) + K.sum(K.square(y_pred[:,:,:,3])) + epsilon)



# Computing Precision 
def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

    
# Computing Sensitivity      
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())


# Computing Specificity
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

# %%
IMG_SIZE=128

# %%
def build_unet(inputs, ker_init, dropout):
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(inputs)
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv1)
    merge1 = concatenate([inputs,conv1], axis = 3)
    
    pool = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)
    merge = concatenate([pool,conv], axis = 3)
    
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv2)
    merge2 = concatenate([pool1,conv2], axis = 3)
    
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv3)
    merge3 = concatenate([pool2,conv3], axis = 3)
    
    
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool4)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv5)
    drop5 = Dropout(dropout)(conv5)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(drop5))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)
    
    up = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv9))
    merge = concatenate([conv1,up], axis = 3)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)
    
    conv10 = Conv2D(4, (1,1), activation = 'softmax')(conv)
    
    return Model(inputs = inputs, outputs = conv10)

input_layer = Input((IMG_SIZE, IMG_SIZE, 2))

model2 = build_unet(input_layer, 'he_normal', 0.2)
model2.compile(loss="categorical_crossentropy", optimizer=keras.optimizers.Nadam(learning_rate=0.001), metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, dice_coef_edema ,dice_coef_enhancing] )

# %%
plot_model(model2, 
           show_shapes = True,
           show_dtype=False,
           show_layer_names = True, 
           rankdir = 'TB', 
           expand_nested = True, 
           dpi = 70)

# %%
# lists of directories with studies
train_and_val_directories = [f.path for f in os.scandir(TRAIN_DATASET_PATH) if f.is_dir()]

# file BraTS20_Training_355 has ill formatted name for for seg.nii file
train_and_val_directories.remove(TRAIN_DATASET_PATH+'BraTS20_Training_355')


def pathListIntoIds(dirList):
    x = []
    for i in range(0,len(dirList)):
        x.append(dirList[i][dirList[i].rfind('/')+1:])
    return x

train_and_test_ids = pathListIntoIds(train_and_val_directories); 

    
train_test_ids, val_ids = train_test_split(train_and_test_ids,test_size=0.2) 
train_ids, test_ids = train_test_split(train_test_ids,test_size=0.15)

# %%
print(len(train_ids))
print(len(val_ids))
print(len(test_ids))

# %%
class DataGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, dim=(IMG_SIZE,IMG_SIZE), batch_size = 1, n_channels = 2, shuffle=True):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))
        y = np.zeros((self.batch_size*VOLUME_SLICES, 240, 240))
        Y = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, 4))

        
        # Generate data
        for c, i in enumerate(Batch_ids):
            case_path = os.path.join(TRAIN_DATASET_PATH, i)

            data_path = os.path.join(case_path, f'{i}_flair.nii');
            flair = nib.load(data_path).get_fdata()    

            data_path = os.path.join(case_path, f'{i}_t1ce.nii');
            ce = nib.load(data_path).get_fdata()
            
            data_path = os.path.join(case_path, f'{i}_seg.nii');
            seg = nib.load(data_path).get_fdata()
        
            for j in range(VOLUME_SLICES):
                 X[j +VOLUME_SLICES*c,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));
                 X[j +VOLUME_SLICES*c,:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));

                 y[j +VOLUME_SLICES*c] = seg[:,:,j+VOLUME_START_AT];
                    
        # Generate masks
        y[y==4] = 3;
        mask = tf.one_hot(y, 4);
        Y = tf.image.resize(mask, (IMG_SIZE, IMG_SIZE));
        return X/np.max(X), Y
        
training_generator = DataGenerator(train_ids)
valid_generator = DataGenerator(val_ids)
test_generator = DataGenerator(test_ids)

# %%
def showDataLayout():
    plt.bar(["Train","Valid","Test"],
    [len(train_ids), len(val_ids), len(test_ids)], align='center',color=[ 'green','red', 'blue'])
    plt.legend()

    plt.ylabel('Number of images')
    plt.title('Data distribution')

    plt.show()
    
showDataLayout()

# %%
csv_logger = CSVLogger('training2.log', separator=',', append=False)


callbacks = [
#     keras.callbacks.EarlyStopping(monitor='loss', min_delta=0,
#                               patience=2, verbose=1, mode='auto'),
      keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              patience=2, min_lr=0.000001, verbose=1),
#  keras.callbacks.ModelCheckpoint(filepath = 'model_.{epoch:02d}-{val_loss:.6f}.m5',
#                             verbose=1, save_best_only=True, save_weights_only = True)
        csv_logger
    ]

# %%
model2.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 2  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 32  608         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 32  9248        ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 32)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 64)   18496       ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 64)   36928       ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 128)  147584      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0          ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 256)  590080      ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)   0           ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 512)    1180160     ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 512)    2359808     ['conv2d_8[0][0]']
#
#  dropout (Dropout)              (None, 8, 8, 512)    0           ['conv2d_9[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 512)  0           ['dropout[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 256)  524544      ['up_sampling2d[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 16, 16, 512)  0           ['conv2d_7[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 256)  1179904     ['concatenate_4[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 256)  590080      ['conv2d_11[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 256)  0          ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 128)  131200      ['up_sampling2d_1[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 32, 32, 256)  0           ['conv2d_5[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 128)  295040      ['concatenate_5[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 128)  147584      ['conv2d_14[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 128)  0          ['conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 64, 64, 64)   32832       ['up_sampling2d_2[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 128)  0           ['conv2d_3[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 64, 64, 64)   73792       ['concatenate_6[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 64, 64, 64)   36928       ['conv2d_17[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 64  0          ['conv2d_18[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 128, 128, 32  8224        ['up_sampling2d_3[0][0]']
#                                 )
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 64  0           ['conv2d_1[0][0]',
#                                 )                                 'conv2d_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_7[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 128, 128, 32  9248        ['conv2d_20[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 128, 128, 4)  132         ['conv2d_21[0][0]']
#
# ==================================================================================================
# Total params: 7,759,908
# Trainable params: 7,759,908
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
K.clear_session()
history =  model2.fit(training_generator,
                     epochs=35,
                     steps_per_epoch=len(train_ids),
                     callbacks= callbacks,
                     validation_data = valid_generator
                     )  
model2.save("model_run2.h5")
# Out:
# Epoch 1/35
# 2024-02-21 21:08:33.920912: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 249/249 [==============================] - 308s 1s/step - loss: 0.3064 - accuracy: 0.9826 - mean_io_u: 0.6380 - dice_coef: 0.2707 - precision: 0.9787 - sensitivity: 0.9574 - specificity: 0.9948 - dice_coef_necrotic: 0.0633 - dice_coef_edema: 0.1372 - dice_coef_enhancing: 0.0661 - val_loss: 0.0686 - val_accuracy: 0.9837 - val_mean_io_u: 0.6711 - val_dice_coef: 0.2812 - val_precision: 0.9838 - val_sensitivity: 0.9837 - val_specificity: 0.9946 - val_dice_coef_necrotic: 0.0570 - val_dice_coef_edema: 0.1060 - val_dice_coef_enhancing: 0.0449 - lr: 0.0010
# Epoch 2/35
# 249/249 [==============================] - 199s 797ms/step - loss: 0.0635 - accuracy: 0.9833 - mean_io_u: 0.6495 - dice_coef: 0.3073 - precision: 0.9872 - sensitivity: 0.9793 - specificity: 0.9957 - dice_coef_necrotic: 0.1407 - dice_coef_edema: 0.2381 - dice_coef_enhancing: 0.1399 - val_loss: 0.0578 - val_accuracy: 0.9837 - val_mean_io_u: 0.6846 - val_dice_coef: 0.3018 - val_precision: 0.9845 - val_sensitivity: 0.9836 - val_specificity: 0.9948 - val_dice_coef_necrotic: 0.0867 - val_dice_coef_edema: 0.1891 - val_dice_coef_enhancing: 0.0891 - lr: 0.0010
# Epoch 3/35
# 249/249 [==============================] - 198s 795ms/step - loss: 0.0545 - accuracy: 0.9842 - mean_io_u: 0.6576 - dice_coef: 0.3356 - precision: 0.9899 - sensitivity: 0.9794 - specificity: 0.9965 - dice_coef_necrotic: 0.1772 - dice_coef_edema: 0.3186 - dice_coef_enhancing: 0.2173 - val_loss: 0.0689 - val_accuracy: 0.9844 - val_mean_io_u: 0.7296 - val_dice_coef: 0.3222 - val_precision: 0.9884 - val_sensitivity: 0.9803 - val_specificity: 0.9961 - val_dice_coef_necrotic: 0.1337 - val_dice_coef_edema: 0.2847 - val_dice_coef_enhancing: 0.1932 - lr: 0.0010
# Epoch 4/35
# 249/249 [==============================] - 198s 794ms/step - loss: 0.0565 - accuracy: 0.9850 - mean_io_u: 0.7072 - dice_coef: 0.3484 - precision: 0.9897 - sensitivity: 0.9805 - specificity: 0.9965 - dice_coef_necrotic: 0.1775 - dice_coef_edema: 0.3412 - dice_coef_enhancing: 0.2685 - val_loss: 0.0522 - val_accuracy: 0.9847 - val_mean_io_u: 0.6481 - val_dice_coef: 0.3344 - val_precision: 0.9866 - val_sensitivity: 0.9837 - val_specificity: 0.9955 - val_dice_coef_necrotic: 0.1160 - val_dice_coef_edema: 0.2490 - val_dice_coef_enhancing: 0.2415 - lr: 0.0010
# Epoch 5/35
# 249/249 [==============================] - 198s 795ms/step - loss: 0.0466 - accuracy: 0.9853 - mean_io_u: 0.7176 - dice_coef: 0.3704 - precision: 0.9908 - sensitivity: 0.9806 - specificity: 0.9969 - dice_coef_necrotic: 0.2048 - dice_coef_edema: 0.3752 - dice_coef_enhancing: 0.3356 - val_loss: 0.0554 - val_accuracy: 0.9853 - val_mean_io_u: 0.7863 - val_dice_coef: 0.3572 - val_precision: 0.9885 - val_sensitivity: 0.9836 - val_specificity: 0.9961 - val_dice_coef_necrotic: 0.1618 - val_dice_coef_edema: 0.2650 - val_dice_coef_enhancing: 0.2618 - lr: 0.0010
# Epoch 6/35
# 249/249 [==============================] - 198s 792ms/step - loss: 0.0380 - accuracy: 0.9876 - mean_io_u: 0.7762 - dice_coef: 0.4078 - precision: 0.9919 - sensitivity: 0.9833 - specificity: 0.9972 - dice_coef_necrotic: 0.2474 - dice_coef_edema: 0.4700 - dice_coef_enhancing: 0.4125 - val_loss: 0.0367 - val_accuracy: 0.9886 - val_mean_io_u: 0.7391 - val_dice_coef: 0.4084 - val_precision: 0.9940 - val_sensitivity: 0.9823 - val_specificity: 0.9978 - val_dice_coef_necrotic: 0.2959 - val_dice_coef_edema: 0.4564 - val_dice_coef_enhancing: 0.4149 - lr: 0.0010
# Epoch 7/35
# 249/249 [==============================] - 198s 795ms/step - loss: 0.0346 - accuracy: 0.9884 - mean_io_u: 0.7810 - dice_coef: 0.4321 - precision: 0.9922 - sensitivity: 0.9846 - specificity: 0.9973 - dice_coef_necrotic: 0.2786 - dice_coef_edema: 0.5229 - dice_coef_enhancing: 0.4441 - val_loss: 0.0353 - val_accuracy: 0.9883 - val_mean_io_u: 0.8127 - val_dice_coef: 0.4161 - val_precision: 0.9898 - val_sensitivity: 0.9867 - val_specificity: 0.9966 - val_dice_coef_necrotic: 0.2567 - val_dice_coef_edema: 0.5065 - val_dice_coef_enhancing: 0.3099 - lr: 0.0010
# Epoch 8/35
# 249/249 [==============================] - 198s 793ms/step - loss: 0.0339 - accuracy: 0.9887 - mean_io_u: 0.7907 - dice_coef: 0.4448 - precision: 0.9921 - sensitivity: 0.9852 - specificity: 0.9973 - dice_coef_necrotic: 0.2921 - dice_coef_edema: 0.5414 - dice_coef_enhancing: 0.4751 - val_loss: 0.0350 - val_accuracy: 0.9869 - val_mean_io_u: 0.8125 - val_dice_coef: 0.4414 - val_precision: 0.9912 - val_sensitivity: 0.9834 - val_specificity: 0.9970 - val_dice_coef_necrotic: 0.3061 - val_dice_coef_edema: 0.4287 - val_dice_coef_enhancing: 0.4924 - lr: 0.0010
# Epoch 9/35
# 249/249 [==============================] - 201s 807ms/step - loss: 0.0285 - accuracy: 0.9901 - mean_io_u: 0.7888 - dice_coef: 0.4827 - precision: 0.9929 - sensitivity: 0.9871 - specificity: 0.9975 - dice_coef_necrotic: 0.3452 - dice_coef_edema: 0.6061 - dice_coef_enhancing: 0.5244 - val_loss: 0.0311 - val_accuracy: 0.9890 - val_mean_io_u: 0.8014 - val_dice_coef: 0.4797 - val_precision: 0.9927 - val_sensitivity: 0.9850 - val_specificity: 0.9975 - val_dice_coef_necrotic: 0.3891 - val_dice_coef_edema: 0.5979 - val_dice_coef_enhancing: 0.5165 - lr: 0.0010
# Epoch 10/35
# 249/249 [==============================] - 197s 792ms/step - loss: 0.0291 - accuracy: 0.9900 - mean_io_u: 0.7889 - dice_coef: 0.4807 - precision: 0.9928 - sensitivity: 0.9869 - specificity: 0.9975 - dice_coef_necrotic: 0.3501 - dice_coef_edema: 0.6000 - dice_coef_enhancing: 0.5129 - val_loss: 0.0312 - val_accuracy: 0.9904 - val_mean_io_u: 0.8059 - val_dice_coef: 0.4753 - val_precision: 0.9929 - val_sensitivity: 0.9872 - val_specificity: 0.9975 - val_dice_coef_necrotic: 0.3727 - val_dice_coef_edema: 0.5389 - val_dice_coef_enhancing: 0.5303 - lr: 0.0010
# Epoch 11/35
# 249/249 [==============================] - 198s 795ms/step - loss: 0.0256 - accuracy: 0.9909 - mean_io_u: 0.7945 - dice_coef: 0.5135 - precision: 0.9932 - sensitivity: 0.9881 - specificity: 0.9977 - dice_coef_necrotic: 0.4040 - dice_coef_edema: 0.6405 - dice_coef_enhancing: 0.5708 - val_loss: 0.0269 - val_accuracy: 0.9911 - val_mean_io_u: 0.7830 - val_dice_coef: 0.5111 - val_precision: 0.9934 - val_sensitivity: 0.9882 - val_specificity: 0.9977 - val_dice_coef_necrotic: 0.4604 - val_dice_coef_edema: 0.5708 - val_dice_coef_enhancing: 0.5584 - lr: 0.0010
# Epoch 12/35
# 249/249 [==============================] - 196s 785ms/step - loss: 0.0244 - accuracy: 0.9912 - mean_io_u: 0.8101 - dice_coef: 0.5270 - precision: 0.9933 - sensitivity: 0.9885 - specificity: 0.9977 - dice_coef_necrotic: 0.4248 - dice_coef_edema: 0.6502 - dice_coef_enhancing: 0.5892 - val_loss: 0.0271 - val_accuracy: 0.9914 - val_mean_io_u: 0.8187 - val_dice_coef: 0.5297 - val_precision: 0.9935 - val_sensitivity: 0.9887 - val_specificity: 0.9977 - val_dice_coef_necrotic: 0.4235 - val_dice_coef_edema: 0.6410 - val_dice_coef_enhancing: 0.5811 - lr: 0.0010
# Epoch 13/35
# 249/249 [==============================] - 200s 801ms/step - loss: 0.0230 - accuracy: 0.9916 - mean_io_u: 0.8071 - dice_coef: 0.5408 - precision: 0.9936 - sensitivity: 0.9891 - specificity: 0.9978 - dice_coef_necrotic: 0.4460 - dice_coef_edema: 0.6700 - dice_coef_enhancing: 0.5988 - val_loss: 0.0261 - val_accuracy: 0.9913 - val_mean_io_u: 0.8136 - val_dice_coef: 0.5180 - val_precision: 0.9938 - val_sensitivity: 0.9884 - val_specificity: 0.9978 - val_dice_coef_necrotic: 0.4280 - val_dice_coef_edema: 0.5895 - val_dice_coef_enhancing: 0.5996 - lr: 0.0010
# Epoch 14/35
# 249/249 [==============================] - 199s 798ms/step - loss: 0.0241 - accuracy: 0.9915 - mean_io_u: 0.7885 - dice_coef: 0.5362 - precision: 0.9934 - sensitivity: 0.9889 - specificity: 0.9977 - dice_coef_necrotic: 0.4380 - dice_coef_edema: 0.6655 - dice_coef_enhancing: 0.5961 - val_loss: 0.0270 - val_accuracy: 0.9914 - val_mean_io_u: 0.7598 - val_dice_coef: 0.5361 - val_precision: 0.9929 - val_sensitivity: 0.9894 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.4421 - val_dice_coef_edema: 0.6061 - val_dice_coef_enhancing: 0.5813 - lr: 0.0010
# Epoch 15/35
# 249/249 [==============================] - ETA: 0s - loss: 0.0382 - accuracy: 0.9893 - mean_io_u: 0.7866 - dice_coef: 0.4757 - precision: 0.9911 - sensitivity: 0.9865 - specificity: 0.9970 - dice_coef_necrotic: 0.3608 - dice_coef_edema: 0.5387 - dice_coef_enhancing: 0.4630
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 249/249 [==============================] - 197s 792ms/step - loss: 0.0382 - accuracy: 0.9893 - mean_io_u: 0.7866 - dice_coef: 0.4757 - precision: 0.9911 - sensitivity: 0.9865 - specificity: 0.9970 - dice_coef_necrotic: 0.3608 - dice_coef_edema: 0.5387 - dice_coef_enhancing: 0.4630 - val_loss: 0.0692 - val_accuracy: 0.9785 - val_mean_io_u: 0.7651 - val_dice_coef: 0.3318 - val_precision: 0.9860 - val_sensitivity: 0.9715 - val_specificity: 0.9953 - val_dice_coef_necrotic: 0.1774 - val_dice_coef_edema: 0.2965 - val_dice_coef_enhancing: 0.2200 - lr: 0.0010
# Epoch 16/35
# 249/249 [==============================] - 195s 783ms/step - loss: 0.0497 - accuracy: 0.9858 - mean_io_u: 0.7637 - dice_coef: 0.3691 - precision: 0.9889 - sensitivity: 0.9830 - specificity: 0.9963 - dice_coef_necrotic: 0.2029 - dice_coef_edema: 0.3849 - dice_coef_enhancing: 0.3344 - val_loss: 0.0375 - val_accuracy: 0.9886 - val_mean_io_u: 0.7378 - val_dice_coef: 0.4270 - val_precision: 0.9915 - val_sensitivity: 0.9855 - val_specificity: 0.9971 - val_dice_coef_necrotic: 0.3084 - val_dice_coef_edema: 0.5098 - val_dice_coef_enhancing: 0.4432 - lr: 2.0000e-04
# Epoch 17/35
# 249/249 [==============================] - ETA: 0s - loss: 0.0316 - accuracy: 0.9898 - mean_io_u: 0.7400 - dice_coef: 0.4773 - precision: 0.9921 - sensitivity: 0.9871 - specificity: 0.9973 - dice_coef_necrotic: 0.3470 - dice_coef_edema: 0.5865 - dice_coef_enhancing: 0.5309
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 249/249 [==============================] - 197s 790ms/step - loss: 0.0316 - accuracy: 0.9898 - mean_io_u: 0.7400 - dice_coef: 0.4773 - precision: 0.9921 - sensitivity: 0.9871 - specificity: 0.9973 - dice_coef_necrotic: 0.3470 - dice_coef_edema: 0.5865 - dice_coef_enhancing: 0.5309 - val_loss: 0.0297 - val_accuracy: 0.9905 - val_mean_io_u: 0.7537 - val_dice_coef: 0.5005 - val_precision: 0.9925 - val_sensitivity: 0.9883 - val_specificity: 0.9974 - val_dice_coef_necrotic: 0.3847 - val_dice_coef_edema: 0.5514 - val_dice_coef_enhancing: 0.5561 - lr: 2.0000e-04
# Epoch 18/35
# 249/249 [==============================] - 197s 791ms/step - loss: 0.0243 - accuracy: 0.9913 - mean_io_u: 0.7612 - dice_coef: 0.5264 - precision: 0.9935 - sensitivity: 0.9887 - specificity: 0.9978 - dice_coef_necrotic: 0.4250 - dice_coef_edema: 0.6496 - dice_coef_enhancing: 0.5961 - val_loss: 0.0273 - val_accuracy: 0.9911 - val_mean_io_u: 0.7619 - val_dice_coef: 0.5187 - val_precision: 0.9929 - val_sensitivity: 0.9889 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.4224 - val_dice_coef_edema: 0.6028 - val_dice_coef_enhancing: 0.5657 - lr: 4.0000e-05
# Epoch 19/35
# 249/249 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 0.9916 - mean_io_u: 0.7670 - dice_coef: 0.5376 - precision: 0.9936 - sensitivity: 0.9890 - specificity: 0.9978 - dice_coef_necrotic: 0.4429 - dice_coef_edema: 0.6632 - dice_coef_enhancing: 0.6085
# Epoch 19: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 249/249 [==============================] - 199s 798ms/step - loss: 0.0234 - accuracy: 0.9916 - mean_io_u: 0.7670 - dice_coef: 0.5376 - precision: 0.9936 - sensitivity: 0.9890 - specificity: 0.9978 - dice_coef_necrotic: 0.4429 - dice_coef_edema: 0.6632 - dice_coef_enhancing: 0.6085 - val_loss: 0.0272 - val_accuracy: 0.9912 - val_mean_io_u: 0.7700 - val_dice_coef: 0.5252 - val_precision: 0.9926 - val_sensitivity: 0.9893 - val_specificity: 0.9975 - val_dice_coef_necrotic: 0.4217 - val_dice_coef_edema: 0.6141 - val_dice_coef_enhancing: 0.5583 - lr: 4.0000e-05
# Epoch 20/35
# 249/249 [==============================] - 199s 797ms/step - loss: 0.0227 - accuracy: 0.9918 - mean_io_u: 0.7725 - dice_coef: 0.5440 - precision: 0.9936 - sensitivity: 0.9894 - specificity: 0.9978 - dice_coef_necrotic: 0.4477 - dice_coef_edema: 0.6754 - dice_coef_enhancing: 0.6128 - val_loss: 0.0266 - val_accuracy: 0.9913 - val_mean_io_u: 0.7699 - val_dice_coef: 0.5267 - val_precision: 0.9929 - val_sensitivity: 0.9892 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.4327 - val_dice_coef_edema: 0.6171 - val_dice_coef_enhancing: 0.5709 - lr: 8.0000e-06
# Epoch 21/35
# 249/249 [==============================] - ETA: 0s - loss: 0.0225 - accuracy: 0.9919 - mean_io_u: 0.7744 - dice_coef: 0.5453 - precision: 0.9937 - sensitivity: 0.9894 - specificity: 0.9978 - dice_coef_necrotic: 0.4512 - dice_coef_edema: 0.6766 - dice_coef_enhancing: 0.6182
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 249/249 [==============================] - 195s 783ms/step - loss: 0.0225 - accuracy: 0.9919 - mean_io_u: 0.7744 - dice_coef: 0.5453 - precision: 0.9937 - sensitivity: 0.9894 - specificity: 0.9978 - dice_coef_necrotic: 0.4512 - dice_coef_edema: 0.6766 - dice_coef_enhancing: 0.6182 - val_loss: 0.0265 - val_accuracy: 0.9914 - val_mean_io_u: 0.7749 - val_dice_coef: 0.5283 - val_precision: 0.9929 - val_sensitivity: 0.9893 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.4354 - val_dice_coef_edema: 0.6158 - val_dice_coef_enhancing: 0.5743 - lr: 8.0000e-06
# Epoch 22/35
# 249/249 [==============================] - 197s 789ms/step - loss: 0.0224 - accuracy: 0.9920 - mean_io_u: 0.7775 - dice_coef: 0.5470 - precision: 0.9937 - sensitivity: 0.9895 - specificity: 0.9979 - dice_coef_necrotic: 0.4542 - dice_coef_edema: 0.6773 - dice_coef_enhancing: 0.6208 - val_loss: 0.0265 - val_accuracy: 0.9914 - val_mean_io_u: 0.7749 - val_dice_coef: 0.5286 - val_precision: 0.9929 - val_sensitivity: 0.9893 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.4364 - val_dice_coef_edema: 0.6171 - val_dice_coef_enhancing: 0.5743 - lr: 1.6000e-06
# Epoch 23/35
# 249/249 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9920 - mean_io_u: 0.7778 - dice_coef: 0.5473 - precision: 0.9937 - sensitivity: 0.9895 - specificity: 0.9979 - dice_coef_necrotic: 0.4548 - dice_coef_edema: 0.6778 - dice_coef_enhancing: 0.6213
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1e-06.
# 249/249 [==============================] - 197s 791ms/step - loss: 0.0223 - accuracy: 0.9920 - mean_io_u: 0.7778 - dice_coef: 0.5473 - precision: 0.9937 - sensitivity: 0.9895 - specificity: 0.9979 - dice_coef_necrotic: 0.4548 - dice_coef_edema: 0.6778 - dice_coef_enhancing: 0.6213 - val_loss: 0.0265 - val_accuracy: 0.9914 - val_mean_io_u: 0.7752 - val_dice_coef: 0.5289 - val_precision: 0.9929 - val_sensitivity: 0.9893 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.4367 - val_dice_coef_edema: 0.6173 - val_dice_coef_enhancing: 0.5747 - lr: 1.6000e-06
# Epoch 24/35
# 249/249 [==============================] - 198s 794ms/step - loss: 0.0223 - accuracy: 0.9920 - mean_io_u: 0.7782 - dice_coef: 0.5477 - precision: 0.9937 - sensitivity: 0.9895 - specificity: 0.9979 - dice_coef_necrotic: 0.4551 - dice_coef_edema: 0.6782 - dice_coef_enhancing: 0.6216 - val_loss: 0.0264 - val_accuracy: 0.9914 - val_mean_io_u: 0.7753 - val_dice_coef: 0.5290 - val_precision: 0.9929 - val_sensitivity: 0.9893 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.4371 - val_dice_coef_edema: 0.6181 - val_dice_coef_enhancing: 0.5745 - lr: 1.0000e-06
# Epoch 25/35
# 249/249 [==============================] - 199s 798ms/step - loss: 0.0223 - accuracy: 0.9920 - mean_io_u: 0.7781 - dice_coef: 0.5478 - precision: 0.9938 - sensitivity: 0.9895 - specificity: 0.9979 - dice_coef_necrotic: 0.4556 - dice_coef_edema: 0.6787 - dice_coef_enhancing: 0.6222 - val_loss: 0.0264 - val_accuracy: 0.9914 - val_mean_io_u: 0.7754 - val_dice_coef: 0.5292 - val_precision: 0.9929 - val_sensitivity: 0.9893 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.4373 - val_dice_coef_edema: 0.6184 - val_dice_coef_enhancing: 0.5746 - lr: 1.0000e-06
# Epoch 26/35
# 249/249 [==============================] - 199s 799ms/step - loss: 0.0223 - accuracy: 0.9920 - mean_io_u: 0.7782 - dice_coef: 0.5479 - precision: 0.9937 - sensitivity: 0.9895 - specificity: 0.9979 - dice_coef_necrotic: 0.4558 - dice_coef_edema: 0.6795 - dice_coef_enhancing: 0.6218 - val_loss: 0.0264 - val_accuracy: 0.9914 - val_mean_io_u: 0.7757 - val_dice_coef: 0.5294 - val_precision: 0.9929 - val_sensitivity: 0.9893 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.4372 - val_dice_coef_edema: 0.6181 - val_dice_coef_enhancing: 0.5748 - lr: 1.0000e-06
# Epoch 27/35
# 249/249 [==============================] - 198s 793ms/step - loss: 0.0222 - accuracy: 0.9920 - mean_io_u: 0.7787 - dice_coef: 0.5484 - precision: 0.9937 - sensitivity: 0.9895 - specificity: 0.9978 - dice_coef_necrotic: 0.4555 - dice_coef_edema: 0.6793 - dice_coef_enhancing: 0.6218 - val_loss: 0.0264 - val_accuracy: 0.9914 - val_mean_io_u: 0.7759 - val_dice_coef: 0.5296 - val_precision: 0.9929 - val_sensitivity: 0.9893 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.4376 - val_dice_coef_edema: 0.6187 - val_dice_coef_enhancing: 0.5749 - lr: 1.0000e-06
# Epoch 28/35
# 249/249 [==============================] - 198s 793ms/step - loss: 0.0222 - accuracy: 0.9920 - mean_io_u: 0.7786 - dice_coef: 0.5485 - precision: 0.9937 - sensitivity: 0.9895 - specificity: 0.9979 - dice_coef_necrotic: 0.4562 - dice_coef_edema: 0.6797 - dice_coef_enhancing: 0.6227 - val_loss: 0.0264 - val_accuracy: 0.9914 - val_mean_io_u: 0.7761 - val_dice_coef: 0.5298 - val_precision: 0.9929 - val_sensitivity: 0.9893 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.4377 - val_dice_coef_edema: 0.6188 - val_dice_coef_enhancing: 0.5752 - lr: 1.0000e-06
# Epoch 29/35
# 249/249 [==============================] - 198s 795ms/step - loss: 0.0222 - accuracy: 0.9920 - mean_io_u: 0.7789 - dice_coef: 0.5488 - precision: 0.9937 - sensitivity: 0.9896 - specificity: 0.9979 - dice_coef_necrotic: 0.4567 - dice_coef_edema: 0.6803 - dice_coef_enhancing: 0.6228 - val_loss: 0.0264 - val_accuracy: 0.9914 - val_mean_io_u: 0.7763 - val_dice_coef: 0.5301 - val_precision: 0.9929 - val_sensitivity: 0.9894 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.4379 - val_dice_coef_edema: 0.6190 - val_dice_coef_enhancing: 0.5754 - lr: 1.0000e-06
# Epoch 30/35
# 249/249 [==============================] - 196s 786ms/step - loss: 0.0222 - accuracy: 0.9920 - mean_io_u: 0.7792 - dice_coef: 0.5491 - precision: 0.9937 - sensitivity: 0.9896 - specificity: 0.9979 - dice_coef_necrotic: 0.4567 - dice_coef_edema: 0.6801 - dice_coef_enhancing: 0.6231 - val_loss: 0.0264 - val_accuracy: 0.9914 - val_mean_io_u: 0.7765 - val_dice_coef: 0.5303 - val_precision: 0.9929 - val_sensitivity: 0.9894 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.4382 - val_dice_coef_edema: 0.6193 - val_dice_coef_enhancing: 0.5755 - lr: 1.0000e-06
# Epoch 31/35
# 249/249 [==============================] - 198s 793ms/step - loss: 0.0222 - accuracy: 0.9920 - mean_io_u: 0.7793 - dice_coef: 0.5493 - precision: 0.9938 - sensitivity: 0.9896 - specificity: 0.9979 - dice_coef_necrotic: 0.4575 - dice_coef_edema: 0.6807 - dice_coef_enhancing: 0.6235 - val_loss: 0.0264 - val_accuracy: 0.9914 - val_mean_io_u: 0.7770 - val_dice_coef: 0.5305 - val_precision: 0.9929 - val_sensitivity: 0.9894 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.4378 - val_dice_coef_edema: 0.6189 - val_dice_coef_enhancing: 0.5758 - lr: 1.0000e-06
# Epoch 32/35
# 249/249 [==============================] - 200s 801ms/step - loss: 0.0221 - accuracy: 0.9920 - mean_io_u: 0.7798 - dice_coef: 0.5496 - precision: 0.9937 - sensitivity: 0.9896 - specificity: 0.9979 - dice_coef_necrotic: 0.4569 - dice_coef_edema: 0.6810 - dice_coef_enhancing: 0.6233 - val_loss: 0.0263 - val_accuracy: 0.9914 - val_mean_io_u: 0.7769 - val_dice_coef: 0.5307 - val_precision: 0.9929 - val_sensitivity: 0.9894 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.4383 - val_dice_coef_edema: 0.6197 - val_dice_coef_enhancing: 0.5760 - lr: 1.0000e-06
# Epoch 33/35
# 249/249 [==============================] - 198s 793ms/step - loss: 0.0221 - accuracy: 0.9920 - mean_io_u: 0.7798 - dice_coef: 0.5498 - precision: 0.9937 - sensitivity: 0.9896 - specificity: 0.9979 - dice_coef_necrotic: 0.4574 - dice_coef_edema: 0.6818 - dice_coef_enhancing: 0.6238 - val_loss: 0.0263 - val_accuracy: 0.9914 - val_mean_io_u: 0.7774 - val_dice_coef: 0.5310 - val_precision: 0.9929 - val_sensitivity: 0.9894 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.4386 - val_dice_coef_edema: 0.6196 - val_dice_coef_enhancing: 0.5765 - lr: 1.0000e-06
# Epoch 34/35
# 249/249 [==============================] - 198s 792ms/step - loss: 0.0221 - accuracy: 0.9920 - mean_io_u: 0.7801 - dice_coef: 0.5501 - precision: 0.9937 - sensitivity: 0.9896 - specificity: 0.9979 - dice_coef_necrotic: 0.4579 - dice_coef_edema: 0.6820 - dice_coef_enhancing: 0.6244 - val_loss: 0.0263 - val_accuracy: 0.9914 - val_mean_io_u: 0.7777 - val_dice_coef: 0.5312 - val_precision: 0.9929 - val_sensitivity: 0.9894 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.4388 - val_dice_coef_edema: 0.6197 - val_dice_coef_enhancing: 0.5767 - lr: 1.0000e-06
# Epoch 35/35
# 249/249 [==============================] - 195s 784ms/step - loss: 0.0221 - accuracy: 0.9920 - mean_io_u: 0.7806 - dice_coef: 0.5505 - precision: 0.9937 - sensitivity: 0.9896 - specificity: 0.9979 - dice_coef_necrotic: 0.4584 - dice_coef_edema: 0.6818 - dice_coef_enhancing: 0.6248 - val_loss: 0.0263 - val_accuracy: 0.9914 - val_mean_io_u: 0.7776 - val_dice_coef: 0.5314 - val_precision: 0.9929 - val_sensitivity: 0.9894 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.4394 - val_dice_coef_edema: 0.6204 - val_dice_coef_enhancing: 0.5773 - lr: 1.0000e-06

# %%
model = keras.models.load_model('/kaggle/working/model_run2.h5', 
                                   custom_objects={ 'accuracy' : tf.keras.metrics.MeanIoU(num_classes=4),
                                                   "dice_coef": dice_coef,
                                                   "precision": precision,
                                                   "sensitivity":sensitivity,
                                                   "specificity":specificity,
                                                   "dice_coef_necrotic": dice_coef_necrotic,
                                                   "dice_coef_edema": dice_coef_edema,
                                                   "dice_coef_enhancing": dice_coef_enhancing
                                                  }, compile=False)

history = pd.read_csv('/kaggle/working/training2.log', sep=',', engine='python')

hist=history

############### ########## ####### #######

# hist=history.history

acc=hist['accuracy']
val_acc=hist['val_accuracy']

epoch=range(len(acc))

loss=hist['loss']
val_loss=hist['val_loss']

train_dice=hist['dice_coef']
val_dice=hist['val_dice_coef']

f,ax=plt.subplots(1,4,figsize=(16,8))

ax[0].plot(epoch,acc,'b',label='Training Accuracy')
ax[0].plot(epoch,val_acc,'r',label='Validation Accuracy')
ax[0].legend()

ax[1].plot(epoch,loss,'b',label='Training Loss')
ax[1].plot(epoch,val_loss,'r',label='Validation Loss')
ax[1].legend()

ax[2].plot(epoch,train_dice,'b',label='Training dice coef')
ax[2].plot(epoch,val_dice,'r',label='Validation dice coef')
ax[2].legend()

ax[3].plot(epoch,hist['mean_io_u'],'b',label='Training mean IOU')
ax[3].plot(epoch,hist['val_mean_io_u'],'r',label='Validation mean IOU')
ax[3].legend()

plt.show()

# %%
# mri type must one of 1) flair 2) t1 3) t1ce 4) t2 ------- or even 5) seg
# returns volume of specified study at `path`
def imageLoader(path):
    image = nib.load(path).get_fdata()
    X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))
    for j in range(VOLUME_SLICES):
        X[j +VOLUME_SLICES*c,:,:,0] = cv2.resize(image[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));
        X[j +VOLUME_SLICES*c,:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));

        y[j +VOLUME_SLICES*c] = seg[:,:,j+VOLUME_START_AT];
    return np.array(image)


# load nifti file at `path`
# and load each slice with mask from volume
# choose the mri type & resize to `IMG_SIZE`
def loadDataFromDir(path, list_of_files, mriType, n_images):
    scans = []
    masks = []
    for i in list_of_files[:n_images]:
        fullPath = glob.glob( i + '/*'+ mriType +'*')[0]
        currentScanVolume = imageLoader(fullPath)
        currentMaskVolume = imageLoader( glob.glob( i + '/*seg*')[0] ) 
        # for each slice in 3D volume, find also it's mask
        for j in range(0, currentScanVolume.shape[2]):
            scan_img = cv2.resize(currentScanVolume[:,:,j], dsize=(IMG_SIZE,IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')
            mask_img = cv2.resize(currentMaskVolume[:,:,j], dsize=(IMG_SIZE,IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')
            scans.append(scan_img[..., np.newaxis])
            masks.append(mask_img[..., np.newaxis])
    return np.array(scans, dtype='float32'), np.array(masks, dtype='float32')
        
#brains_list_test, masks_list_test = loadDataFromDir(VALIDATION_DATASET_PATH, test_directories, "flair", 5)

# %%
def predictByPath(case_path,case):
    files = next(os.walk(case_path))[2]
    X = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE, 2))
  #  y = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE))
    
    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_flair.nii');
    flair=nib.load(vol_path).get_fdata()
    
    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_t1ce.nii');
    ce=nib.load(vol_path).get_fdata() 
    
 #   vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_seg.nii');
 #   seg=nib.load(vol_path).get_fdata()  

    
    for j in range(VOLUME_SLICES):
        X[j,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        X[j,:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
 #       y[j,:,:] = cv2.resize(seg[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        
  #  model.evaluate(x=X,y=y[:,:,:,0], callbacks= callbacks)
    return model.predict(X/np.max(X), verbose=1)


def showPredictsById(case, start_slice = 60):
    path = f"../input/brats20-dataset-training-validation/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_{case}"
    gt = nib.load(os.path.join(path, f'BraTS20_Training_{case}_seg.nii')).get_fdata()
    origImage = nib.load(os.path.join(path, f'BraTS20_Training_{case}_flair.nii')).get_fdata()
    p = predictByPath(path,case)

    core = p[:,:,:,1]
    edema= p[:,:,:,2]
    enhancing = p[:,:,:,3]

    plt.figure(figsize=(18, 50))
    f, axarr = plt.subplots(1,6, figsize = (18, 50)) 

    for i in range(6): # for each image, add brain background
        axarr[i].imshow(cv2.resize(origImage[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE)), cmap="gray", interpolation='none')
    
    axarr[0].imshow(cv2.resize(origImage[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE)), cmap="gray")
    axarr[0].title.set_text('Original image flair')
    curr_gt=cv2.resize(gt[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation = cv2.INTER_NEAREST)
    axarr[1].imshow(curr_gt, cmap="Reds", interpolation='none', alpha=0.3) # ,alpha=0.3,cmap='Reds'
    axarr[1].title.set_text('Ground truth')
    axarr[2].imshow(p[start_slice,:,:,1:4], cmap="Reds", interpolation='none', alpha=0.3)
    axarr[2].title.set_text('all classes')
    axarr[3].imshow(edema[start_slice,:,:], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[3].title.set_text(f'{SEGMENT_CLASSES[1]} predicted')
    axarr[4].imshow(core[start_slice,:,], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[4].title.set_text(f'{SEGMENT_CLASSES[2]} predicted')
    axarr[5].imshow(enhancing[start_slice,:,], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[5].title.set_text(f'{SEGMENT_CLASSES[3]} predicted')
    plt.show()
    
    
showPredictsById(case=test_ids[0][-3:])
showPredictsById(case=test_ids[1][-3:])
showPredictsById(case=test_ids[2][-3:])
showPredictsById(case=test_ids[3][-3:])
showPredictsById(case=test_ids[4][-3:])
showPredictsById(case=test_ids[5][-3:])
showPredictsById(case=test_ids[6][-3:])
# Out:
# 4/4 [==============================] - 4s 303ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 69ms/step
# 4/4 [==============================] - 0s 69ms/step
# 4/4 [==============================] - 0s 69ms/step
# 4/4 [==============================] - 0s 64ms/step

# %%
def predictByPath(case_path,case):
    files = next(os.walk(case_path))[2]
    X = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE, 2))
  #  y = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE))
    
    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_flair.nii');
    flair=nib.load(vol_path).get_fdata()
    
    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_t1ce.nii');
    ce=nib.load(vol_path).get_fdata() 
    
 #   vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_seg.nii');
 #   seg=nib.load(vol_path).get_fdata()  

    
    for j in range(VOLUME_SLICES):
        X[j,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        X[j,:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
 #       y[j,:,:] = cv2.resize(seg[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        
  #  model.evaluate(x=X,y=y[:,:,:,0], callbacks= callbacks)
    return model.predict(X/np.max(X), verbose=1)


def showPredictsById(case, start_slice = 60):
    path = f"../input/brats20-dataset-training-validation/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_{case}"
    gt = nib.load(os.path.join(path, f'BraTS20_Training_{case}_seg.nii')).get_fdata()
    origImage = nib.load(os.path.join(path, f'BraTS20_Training_{case}_t1.nii')).get_fdata()
    p = predictByPath(path,case)

    core = p[:,:,:,1]
    edema= p[:,:,:,2]
    enhancing = p[:,:,:,3]

    plt.figure(figsize=(18, 50))
    f, axarr = plt.subplots(1,6, figsize = (18, 50)) 

    for i in range(6): # for each image, add brain background
        axarr[i].imshow(cv2.resize(origImage[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE)), cmap="gray", interpolation='none')
    
    axarr[0].imshow(cv2.resize(origImage[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE)), cmap="gray")
    axarr[0].title.set_text('Original image t1')
    curr_gt=cv2.resize(gt[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation = cv2.INTER_NEAREST)
    axarr[1].imshow(curr_gt, cmap="Reds", interpolation='none', alpha=0.3) # ,alpha=0.3,cmap='Reds'
    axarr[1].title.set_text('Ground truth')
    axarr[2].imshow(p[start_slice,:,:,1:4], cmap="Reds", interpolation='none', alpha=0.3)
    axarr[2].title.set_text('all classes')
    axarr[3].imshow(edema[start_slice,:,:], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[3].title.set_text(f'{SEGMENT_CLASSES[1]} predicted')
    axarr[4].imshow(core[start_slice,:,], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[4].title.set_text(f'{SEGMENT_CLASSES[2]} predicted')
    axarr[5].imshow(enhancing[start_slice,:,], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[5].title.set_text(f'{SEGMENT_CLASSES[3]} predicted')
    plt.show()
    
    
showPredictsById(case=test_ids[0][-3:])
showPredictsById(case=test_ids[1][-3:])
showPredictsById(case=test_ids[2][-3:])
showPredictsById(case=test_ids[3][-3:])
showPredictsById(case=test_ids[4][-3:])
showPredictsById(case=test_ids[5][-3:])
showPredictsById(case=test_ids[6][-3:])
# Out:
# 4/4 [==============================] - 0s 69ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 69ms/step

# %%
case = case=test_ids[3][-3:]
path = f"../input/brats20-dataset-training-validation/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_{case}"
gt = nib.load(os.path.join(path, f'BraTS20_Training_{case}_seg.nii')).get_fdata()
p = predictByPath(path,case)


core = p[:,:,:,1]
edema= p[:,:,:,2]
enhancing = p[:,:,:,3]


i=40 # slice at
eval_class = 2 #     0 : 'NOT tumor',  1 : 'ENHANCING',    2 : 'CORE',    3 : 'WHOLE'



gt[gt != eval_class] = 1 # use only one class for per class evaluation 

resized_gt = cv2.resize(gt[:,:,i+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

plt.figure()
f, axarr = plt.subplots(1,2) 
axarr[0].imshow(resized_gt, cmap="gray")
axarr[0].title.set_text('ground truth')
axarr[1].imshow(p[i,:,:,eval_class], cmap="gray")
axarr[1].title.set_text(f'predicted class: {SEGMENT_CLASSES[eval_class]}')
plt.show()
# Out:
# 4/4 [==============================] - 0s 66ms/step

# %%
model.compile(loss="categorical_crossentropy", optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, dice_coef_edema, dice_coef_enhancing] )
# Evaluate the model on the test data using `evaluate`
print("Evaluate on test data")
results = model.evaluate(test_generator, batch_size=100, callbacks= callbacks)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 45/45 [==============================] - 15s 289ms/step - loss: 0.0282 - accuracy: 0.9904 - mean_io_u_4: 0.7821 - dice_coef: 0.5525 - precision: 0.9924 - sensitivity: 0.9880 - specificity: 0.9974 - dice_coef_necrotic: 0.4475 - dice_coef_edema: 0.6819 - dice_coef_enhancing: 0.6510
# test loss, test acc: [0.028204917907714844, 0.9904031157493591, 0.782097578048706, 0.5525290369987488, 0.9923559427261353, 0.9879652261734009, 0.9973911046981812, 0.4474785625934601, 0.6819170713424683, 0.6510098576545715]
